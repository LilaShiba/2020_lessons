# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Get Data

# %%
df = pd.read_csv('./sandtander.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# # Clean Data

# %%
# change gender to binary
df['Gender'] = df['Gender'].map( {'Male':1, 'Female':0} )

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France       0   42
# 1          2    15647311      Hill          608     Spain       0   41
# 2          3    15619304      Onio          502    France       0   42
# 3          4    15701354      Boni          699    France       0   39
# 4          5    15737888  Mitchell          850     Spain       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# #### Geography

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
# change country
df['Geography'] = df['Geography'].map( {'France':0, 'Spain':1, 'Germany': 2} )

# %% [markdown]
# #### Take away credit score

# %%
# We could do all this 
# df = df.drop("CreditScore", axis=1)
# df = df.drop("CustomerId", axis=1)
# df = df.drop("RowNumber", axis=1)
# df = df.drop("Surname", axis=1)

data = df.loc[:, "Geography":]
data.head()
# Out:
#    Geography  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          0       0   42       2       0.00              1          1
# 1          1       0   41       1   83807.86              1          0
# 2          0       0   42       8  159660.80              3          1
# 3          0       0   39       1       0.00              2          0
# 4          1       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
creditScore = df['CreditScore']
creditScore.head()
# Out:
# 0    619
# 1    608
# 2    502
# 3    699
# 4    850
# Name: CreditScore, dtype: int64

# %% [markdown]
# # Add Data

# %%
data['creditScore'] = creditScore

# %%
data.head()
# Out:
#    Geography  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          0       0   42       2       0.00              1          1
# 1          1       0   41       1   83807.86              1          0
# 2          0       0   42       8  159660.80              3          1
# 3          0       0   39       1       0.00              2          0
# 4          1       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  creditScore
# 0               1        101348.88       1          619
# 1               1        112542.58       0          608
# 2               0        113931.57       1          502
# 3               0         93826.63       0          699
# 4               1         79084.10       0          850

# %% [markdown]
# # Download

# %%
 def dl_csv(df, filename):
    df.to_csv(filename+".csv", ",")

# %% [markdown]
# # Visualize

# %%
corr = data.corr()

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(corr,cmap='RdYlGn_r', linewidths=1.5, annot=True)

# %%
sns.lineplot(x='NumOfProducts', y='Balance', data = data)

# %%
data.head()
# Out:
#    Geography  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          0       0   42       2       0.00              1          1
# 1          1       0   41       1   83807.86              1          0
# 2          0       0   42       8  159660.80              3          1
# 3          0       0   39       1       0.00              2          0
# 4          1       0   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  creditScore
# 0               1        101348.88       1          619
# 1               1        112542.58       0          608
# 2               0        113931.57       1          502
# 3               0         93826.63       0          699
# 4               1         79084.10       0          850

# %%
plt.subplots(figsize=(10,10))
sns.scatterplot(y='Balance', x='creditScore', hue='Gender', data=data)

# %%
data['creditScore'].describe()
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: creditScore, dtype: float64

# %%
data['Balance'].describe()
# Out:
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: Balance, dtype: float64

# %%
db = data[(data['Balance']>.0)]
db.describe()
# Out:
#          Geography       Gender          Age       Tenure        Balance  \
# count  6383.000000  6383.000000  6383.000000  6383.000000    6383.000000
# mean      0.986370     0.547392    39.197713     4.979633  119827.493793
# std       0.894271     0.497788    10.476208     2.909514   30095.056462
# min       0.000000     0.000000    18.000000     0.000000    3768.690000
# 25%       0.000000     0.000000    32.000000     2.000000  100181.975000
# 50%       1.000000     1.000000    38.000000     5.000000  119839.690000
# 75%       2.000000     1.000000    44.000000     8.000000  139512.290000
# max       2.000000     1.000000    92.000000    10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count    6383.000000  6383.000000     6383.000000      6383.000000
# mean        1.386025     0.699201        0.513552    100717.352956
# std         0.577011     0.458641        0.499855     57380.316584
# min         1.000000     0.000000        0.000000        11.580000
# 25%         1.000000     0.000000        0.000000     51736.850000
# 50%         1.000000     1.000000        1.000000    101139.300000
# 75%         2.000000     1.000000        1.000000    149596.615000
# max         4.000000     1.000000        1.000000    199970.740000
#
#             Exited  creditScore
# count  6383.000000  6383.000000
# mean      0.240796   651.138493
# std       0.427600    96.934609
# min       0.000000   350.000000
# 25%       0.000000   584.000000
# 50%       0.000000   652.000000
# 75%       0.000000   718.000000
# max       1.000000   850.000000

# %%
plt.subplots(figsize=(10,10))
sns.scatterplot(y='Balance', x='EstimatedSalary', hue='Gender', data=db)

# %%
sns.distplot(db['EstimatedSalary'])
